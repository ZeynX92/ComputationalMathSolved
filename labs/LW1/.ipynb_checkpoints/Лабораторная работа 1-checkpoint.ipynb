# %% [markdown]
# # Лабораторная работа 1
#
# **Курс:** 2 курс
# **Среда:** Jupyter Notebook / Google Colab
# **Основные библиотеки:** NumPy, Matplotlib, SciPy

# %% [markdown]
# Метод бисекции f(a) f(b) < 0 делим попопалм промежуток [a, b] и проdеряем f(a)f(c) < 0 f(c)f(b) < 0
#
# Критерий остановки: длина отрезка довольно мала, |b-a|/2 < $epsilon$, где $epsilon$ -- точность
# или же |f(c)| < epsilon
#
# Метож простой итерации lamdba - шаг

# %% [markdown]
# #
